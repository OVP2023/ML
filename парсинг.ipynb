# %% [markdown]
# <a href="https://colab.research.google.com/github/OVP2023/ML/blob/main/%D0%BF%D0%B0%D1%80%D1%81%D0%B8%D0%BD%D0%B3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
table1=pd.read_html('https://www.standards.ru/document.aspx?control=54&search=&sort=%20ASC&month=6&cid=175263&year=2024&page=1', encoding="WINDOWS-1251")
df=pd.DataFrame()
df1=pd.DataFrame()
df=table1[10]
df1['Обозначение']=df['Обозначение']
df1['Заглавие на русском языке']=df['Заглавие на русском языке']
df1['Статус']=df['Статус']
df1=df1.dropna()
#df1.head(39)
# Out:
# /usr/local/lib/python3.10/dist-packages/bs4/__init__.py:228: UserWarning: You provided Unicode markup but also provided a value for from_encoding. Your from_encoding will be ignored.
#   warnings.warn("You provided Unicode markup but also provided a value for from_encoding. Your from_encoding will be ignored.")

# %%
table1=pd.read_html('https://www.standards.ru/document.aspx?control=54&search=&sort=%20ASC&month=6&cid=175263&year=2024&page=2', encoding="WINDOWS-1251")
df=pd.DataFrame()
df2=pd.DataFrame()
df=table1[10]
df2['Обозначение']=df['Обозначение']
df2['Заглавие на русском языке']=df['Заглавие на русском языке']
df2['Статус']=df['Статус']
df2=df2.dropna()
#df2.head(39)
# Out:
# /usr/local/lib/python3.10/dist-packages/bs4/__init__.py:228: UserWarning: You provided Unicode markup but also provided a value for from_encoding. Your from_encoding will be ignored.
#   warnings.warn("You provided Unicode markup but also provided a value for from_encoding. Your from_encoding will be ignored.")

# %%
table1=pd.read_html('https://www.standards.ru/document.aspx?control=54&search=&sort=%20ASC&month=6&cid=175263&year=2024&page=3', encoding="WINDOWS-1251")
df=pd.DataFrame()
df3=pd.DataFrame()
df=table1[10]
df3['Обозначение']=df['Обозначение']
df3['Заглавие на русском языке']=df['Заглавие на русском языке']
df3['Статус']=df['Статус']
df3=df3.dropna()
#df3.head(39)
# Out:
# /usr/local/lib/python3.10/dist-packages/bs4/__init__.py:228: UserWarning: You provided Unicode markup but also provided a value for from_encoding. Your from_encoding will be ignored.
#   warnings.warn("You provided Unicode markup but also provided a value for from_encoding. Your from_encoding will be ignored.")

# %%
df_sum=pd.concat([df1, df2], ignore_index=True)
df_sum=pd.concat([df_sum, df3], ignore_index=True)
df_sum.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 66 entries, 0 to 65
# Data columns (total 3 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Обозначение                66 non-null     object
#  1   Заглавие на русском языке  66 non-null     object
#  2   Статус                     66 non-null     object
# dtypes: object(3)
# memory usage: 1.7+ KB

# %%
df_sum.head(66)
# Out:
#                          Обозначение  \
# 0                        Обозначение
# 1   IEC 60317-27-3(2019)/Amd.1(2024)
# 2               IEC 60317-27-3(2024)
# 3   IEC 60317-27-4(2020)/Amd.1(2024)
# 4               IEC 60317-27-4(2024)
# ..                               ...
# 61          IEC 61558-2-10(2024) EXV
# 62              IEC 61558-2-23(2024)
# 63          IEC 61558-2-23(2024) EXV
# 64                 IEC 61784-3(2024)
# 65   Страницы: 1 / 2 / 3 / 4 / 5 / 6
#
#                             Заглавие на русском языке  \
# 0                           Заглавие на русском языке
# 1   Технические условия на обмоточные провода конк...
# 2   Технические условия на обмоточные провода конк...
# 3   Технические условия на обмоточные провода конк...
# 4   Технические условия на обмоточные провода конк...
# ..                                                ...
# 61  Безопасность трансформаторов, реакторов, источ...
# 62  Безопасность трансформаторов, реакторов, источ...
# ...

# %%
table11=pd.read_html('https://www.standards.ru/document/7531290.aspx', encoding="WINDOWS-1251")
for i in range(1,len(table11)):
    print('!!!->',i,table11[i])
# Out:
# /usr/local/lib/python3.10/dist-packages/bs4/__init__.py:228: UserWarning: You provided Unicode markup but also provided a value for from_encoding. Your from_encoding will be ignored.
#   warnings.warn("You provided Unicode markup but also provided a value for from_encoding. Your from_encoding will be ignored.")
# !!!-> 1                                                    0  \
# 0  ГЛАВНАЯ  ИНФОРМАЦИОННАЯ ПРОДУКЦИЯ  ИЗДАТЕЛЬСКА...
# 1                                            ГЛАВНАЯ
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                                    1                       2  \
# 0             Войти  Регистрация  Поиск  Корзина (0)                     NaN
# 1                           ИНФОРМАЦИОННАЯ ПРОДУКЦИЯ  ИЗДАТЕЛЬСКАЯ ПРОДУКЦИЯ
# 2  Информационная продукция. каталогиМЭКIEC 60269...                     NaN
# ...

# %%
table1=pd.read_html('https://www.standards.ru/document/7531290.aspx', encoding="WINDOWS-1251")
df=pd.DataFrame()
df=table1[13]
df.head(10)
# Out:
# /usr/local/lib/python3.10/dist-packages/bs4/__init__.py:228: UserWarning: You provided Unicode markup but also provided a value for from_encoding. Your from_encoding will be ignored.
#   warnings.warn("You provided Unicode markup but also provided a value for from_encoding. Your from_encoding will be ignored.")
#                                  0  \
# 0                      Обозначение
# 1        Заглавие на русском языке
# 2     Заглавие на английском языке
# 3                              МКС
# 4                    Вид стандарта
# 5  Обозначение заменяемого в части
# 6               Дата опубликования
# 7                   Язык оригинала
# 8     Количество страниц оригинала
# 9       ТК – разработчик стандарта
#
#                                                    1
# 0                      IEC 60269-2(2013)/Amd.2(2024)
# 1  Предохранители плавкие низковольтные. Часть 2....
# 2  Low-voltage fuses - Part 2: Supplementary requ...
# ...

# %%
#Парсим страничку ГОСТа
table1=pd.read_html('https://www.standards.ru/document/7530482.aspx', encoding="WINDOWS-1251")
df=pd.DataFrame()
df=table1[13]
df.head(13)
# Out:
# /usr/local/lib/python3.10/dist-packages/bs4/__init__.py:228: UserWarning: You provided Unicode markup but also provided a value for from_encoding. Your from_encoding will be ignored.
#   warnings.warn("You provided Unicode markup but also provided a value for from_encoding. Your from_encoding will be ignored.")
#                                0  \
# 0                    Обозначение
# 1      Заглавие на русском языке
# 2   Заглавие на английском языке
# 3                            МКС
# 4                  Вид стандарта
# 5    Обозначение заменяемого(ых)
# 6             Дата опубликования
# 7                 Язык оригинала
# 8   Количество страниц оригинала
# 9     ТК – разработчик стандарта
# 10                 Номер издания
# 11                        Статус
# 12                      Код цены
#
#                                                     1
# 0                                 IEC 60092-353(2024)
# 1   Электрооборудование судов. Часть 353. Силовые ...
# ...

# %%
table1=pd.read_html('https://www.standards.ru/document.aspx?control=54&search=&sort=%20ASC&month=6&cid=175263&year=2024&page=1', encoding="WINDOWS-1251")
#table1
# Out:
# /usr/local/lib/python3.10/dist-packages/bs4/__init__.py:228: UserWarning: You provided Unicode markup but also provided a value for from_encoding. Your from_encoding will be ignored.
#   warnings.warn("You provided Unicode markup but also provided a value for from_encoding. Your from_encoding will be ignored.")

# %%
#Парсим ссылки на страничку каждого ГОСТа
import requests
from bs4 import BeautifulSoup
from lxml import html


url = 'https://www.standards.ru/document.aspx?control=54&search=&sort=%20ASC&month=6&cid=175263&year=2024&page=0'

response = requests.get(url)
print(response)

soup = BeautifulSoup(response.text, 'lxml')
#soup
table1 = soup.find_all('td', class_='tx12')
print(len(table1))
k=1
for i in range(1,len(table1)):
    if  k==2:
       print(table1[i]) #четные строки
       k=1
    else:
       k=2
# Out:
# <Response [200]>
# 40
# <td class="tx12" nowrap="">
# <a href="/document/7531290.aspx">IEC 60269-2(2013)/Amd.2(2024)</a>
# </td>
# <td class="tx12" nowrap="">
# <a href="/document/7531307.aspx">IEC 60269-2(2024)</a>
# </td>
# <td class="tx12" nowrap="">
# <a href="/document/7530937.aspx">IEC 60300-1(2024)</a>
# </td>
# <td class="tx12" nowrap="">
# <a href="/document/7530936.aspx">IEC 60317-0-9(2015)/Amd.1(2024)</a>
# </td>
# <td class="tx12" nowrap="">
# <a href="/document/7530945.aspx">IEC 60317-0-9(2024)</a>
# </td>
# <td class="tx12" nowrap="">
# <a href="/document/7531296.aspx">IEC 60317-1(2010)/Amd.1(2024)</a>
# </td>
# <td class="tx12" nowrap="">
# <a href="/document/7531303.aspx">IEC 60317-1(2024)</a>
# </td>
# <td class="tx12" nowrap="">
# <a href="/document/7530946.aspx">IEC 60317-2(2019)/Amd.1(2024)</a>
# </td>
# <td class="tx12" nowrap="">
# <a href="/document/7530953.aspx">IEC 60317-2(2024)</a>
# </td>
# <td class="tx12" nowrap="">
# ...

# %%
Г
