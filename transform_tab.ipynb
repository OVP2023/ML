# %% [markdown]
# <a href="https://colab.research.google.com/github/OVP2023/ML/blob/main/transform_tab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df=pd.read_excel('/content/drive/MyDrive/Stajerovka_осень_2024/Парсинг/table_mek_0124T.xlsx')
df.rename(columns={0:'Обозначение',1:'Заглавие на русском языке',6:'Дата опубликования'}, inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22 entries, 0 to 21
# Data columns (total 15 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Unnamed: 0                 22 non-null     int64
#  1   Обозначение                22 non-null     object
#  2   Заглавие на русском языке  22 non-null     object
#  3   2                          22 non-null     object
#  4   3                          22 non-null     object
#  5   4                          22 non-null     object
#  6   5                          22 non-null     object
#  7   Дата опубликования         22 non-null     object
#  8   7                          22 non-null     object
#  9   8                          22 non-null     object
#  10  9                          22 non-null     object
#  11  10                         22 non-null     object
#  12  11                         17 non-null     object
# ...

# %%
df.head()
# Out:
#    Unnamed: 0                       Обозначение  \
# 0           0                       Обозначение
# 1           1     IEC 60034-5(2020)/Cor.1(2024)
# 2           2                       Обозначение
# 3           3  IEC 60695-2-10(2021)/Cor.1(2024)
# 4           4                       Обозначение
#
#                            Заглавие на русском языке  \
# 0                          Заглавие на русском языке
# 1  Машины электрические вращающиеся. Часть 5. Кла...
# 2                          Заглавие на русском языке
# 3  Испытания на пожароопасность. Часть 2-10. Мето...
# 4                          Заглавие на русском языке
#
#                                                    2                  3  \
# 0                       Заглавие на английском языке                МКС
# 1  Rotating electrical machines - Part 5: Degrees...          29.160.01
# 2                       Заглавие на английском языке                МКС
# ...

# %%
df_new=pd.DataFrame()
df_new=df[df['Обозначение']!='Обозначение']
df_new.head()
# Out:
#    Unnamed: 0                       Обозначение  \
# 1           1     IEC 60034-5(2020)/Cor.1(2024)
# 3           3  IEC 60695-2-10(2021)/Cor.1(2024)
# 5           5              IEC 60794-2-24(2024)
# 7           7                 IEC 61360-7(2024)
# 9           9               IEC 61757-6-1(2024)
#
#                            Заглавие на русском языке  \
# 1  Машины электрические вращающиеся. Часть 5. Кла...
# 3  Испытания на пожароопасность. Часть 2-10. Мето...
# 5  Кабели оптические. Часть 2-24. Кабели внутренн...
# 7  Стандартные типы элементов данных с ассоцииров...
# 9  Датчики волоконно-оптические. Часть 6-1. Измер...
#
#                                                    2  \
# 1  Rotating electrical machines - Part 5: Degrees...
# 3  Fire hazard testing - Part 2-10: Glowing/hot-w...
# 5  Optical fibre cables - Part 2-24: Indoor cable...
# 7  Standard data element types with associated cl...
# 9  Fibre optic sensors - Part 6-1: Displacement m...
#
# ...

# %%
df_new.to_excel('/content/drive/MyDrive/Stajerovka_осень_2024/Парсинг/table_mek_0124NEW.xlsx')
